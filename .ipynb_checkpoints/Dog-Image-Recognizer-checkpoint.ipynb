# %% [markdown]
# ## Import Modules

# %%
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
import cv2
import random
import tensorflow as tf
from tensorflow import keras
from joblib import dump, load
from tkinter import *
from tkinter import filedialog

# %%
main_dir = "dataset"
train_dir = "train"
path = os.path.join(main_dir, train_dir)
images = os.listdir(path)
plt.figure(figsize=(16, 16))

for i in range(10):
   img = random.choice([x for x in images])
   fig = plt.subplot(4, 4, i + 1)
   img = mpimg.imread(os.path.join(path, img))
   fig.imshow(img)

# %%
X = []
y = []
convert = lambda category : int(category == "dog")

for p in os.listdir(path):
    category = p.split(".")[0]
    category = convert(category)
    img_array = cv2.imread(os.path.join(path, p), )
    new_img_array = cv2.resize(img_array, dsize=(80, 80))
    X.append(new_img_array)
    y.append(category)
    
X = np.array(X).reshape(-1, 80, 80, 3)
y = np.array(y)

# %% [markdown]
# ### Normalize Data

# %%
X = X / 255.0

# %% [markdown]
# ### Define CNN model

# %%
model = keras.models.Sequential()

# Adds a densly-connected layer to the model
model.add(keras.layers.Conv2D(32, (3, 3), activation="relu", input_shape=(80, 80, 3)))
model.add(keras.layers.MaxPooling2D((2, 2)))

# Add another layer
model.add(keras.layers.Conv2D(64, (3, 3), activation="relu"))
model.add(keras.layers.MaxPooling2D((2, 2)))

# And another layer
model.add(keras.layers.Conv2D(128, (3, 3), activation="relu"))
model.add(keras.layers.MaxPooling2D((2, 2)))

# Guess what..? Add another layer
model.add(keras.layers.Conv2D(128, (3, 3), activation="relu"))
model.add(keras.layers.MaxPooling2D((2, 2)))

# Flatten, then feed the data to the Dense layer
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(512, activation="relu"))
model.add(keras.layers.Dense(1, activation="sigmoid"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 78, 78, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 39, 39, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 37, 37, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 18, 18, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 8, 8, 128)         0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 128)         147584
#
#  max_pooling2d_3 (MaxPoolin  (None, 3, 3, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 512)               590336
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 831681 (3.17 MB)
# Trainable params: 831681 (3.17 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Complie the model

# %%
model.compile(loss="binary_crossentropy",
              optimizer="adam",
              metrics=["accuracy"])

# %% [markdown]
# ### Fit Model with Training Data

# %%
history = model.fit(X, y, epochs=20, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/20
# 625/625 [==============================] - 61s 98ms/step - loss: 0.0888 - accuracy: 0.9661 - val_loss: 0.6963 - val_accuracy: 0.8220
# Epoch 2/20
# 625/625 [==============================] - 68s 109ms/step - loss: 0.0817 - accuracy: 0.9686 - val_loss: 0.5395 - val_accuracy: 0.8648
# Epoch 3/20
# 625/625 [==============================] - 70s 112ms/step - loss: 0.0643 - accuracy: 0.9754 - val_loss: 0.8288 - val_accuracy: 0.7984
# Epoch 4/20
# 625/625 [==============================] - 71s 113ms/step - loss: 0.0567 - accuracy: 0.9786 - val_loss: 0.6731 - val_accuracy: 0.8332
# Epoch 5/20
# 625/625 [==============================] - 69s 110ms/step - loss: 0.0489 - accuracy: 0.9822 - val_loss: 0.5448 - val_accuracy: 0.8510
# Epoch 6/20
# 625/625 [==============================] - 69s 110ms/step - loss: 0.0441 - accuracy: 0.9843 - val_loss: 1.2144 - val_accuracy: 0.7402
# Epoch 7/20
# 625/625 [==============================] - 69s 110ms/step - loss: 0.0458 - accuracy: 0.9826 - val_loss: 0.7570 - val_accuracy: 0.8398
# Epoch 8/20
# 625/625 [==============================] - 68s 109ms/step - loss: 0.0425 - accuracy: 0.9843 - val_loss: 0.7030 - val_accuracy: 0.8508
# Epoch 9/20
# 625/625 [==============================] - 65s 103ms/step - loss: 0.0331 - accuracy: 0.9887 - val_loss: 0.8455 - val_accuracy: 0.8436
# Epoch 10/20
# 625/625 [==============================] - 66s 105ms/step - loss: 0.0353 - accuracy: 0.9873 - val_loss: 1.0293 - val_accuracy: 0.8070
# Epoch 11/20
# 625/625 [==============================] - 64s 102ms/step - loss: 0.0333 - accuracy: 0.9882 - val_loss: 1.2256 - val_accuracy: 0.8006
# Epoch 12/20
# 625/625 [==============================] - 64s 102ms/step - loss: 0.0354 - accuracy: 0.9872 - val_loss: 0.7649 - val_accuracy: 0.8516
# Epoch 13/20
# 625/625 [==============================] - 65s 105ms/step - loss: 0.0254 - accuracy: 0.9906 - val_loss: 1.3250 - val_accuracy: 0.7902
# Epoch 14/20
# 625/625 [==============================] - 64s 103ms/step - loss: 0.0336 - accuracy: 0.9889 - val_loss: 1.3983 - val_accuracy: 0.7352
# Epoch 15/20
# 625/625 [==============================] - 67s 108ms/step - loss: 0.0340 - accuracy: 0.9883 - val_loss: 0.9282 - val_accuracy: 0.8366
# Epoch 16/20
# 625/625 [==============================] - 64s 103ms/step - loss: 0.0225 - accuracy: 0.9916 - val_loss: 1.8228 - val_accuracy: 0.7520
# Epoch 17/20
# 625/625 [==============================] - 65s 104ms/step - loss: 0.0386 - accuracy: 0.9859 - val_loss: 0.8755 - val_accuracy: 0.8282
# Epoch 18/20
# 625/625 [==============================] - 64s 102ms/step - loss: 0.0272 - accuracy: 0.9901 - val_loss: 0.9792 - val_accuracy: 0.8394
# Epoch 19/20
# 625/625 [==============================] - 64s 102ms/step - loss: 0.0288 - accuracy: 0.9895 - val_loss: 1.4977 - val_accuracy: 0.7662
# Epoch 20/20
# 625/625 [==============================] - 70s 112ms/step - loss: 0.0237 - accuracy: 0.9926 - val_loss: 1.0467 - val_accuracy: 0.8410

# %% [markdown]
# ### Data Model Persistence

# %%
dump(model, "model.joblib")
# Out:
# ['model.joblib']

# %% [markdown]
# ### Reload Data Model

# %%
model = load("model.joblib")

# %% [markdown]
# ### Pre-process Test Data

# %%
train_dir = "test"
path = os.path.join(main_dir, train_dir)

X_test = []
id_line = []

for p in os.listdir(path):
    id_line.append(p.split(".")[0])
    img_array = cv2.imread(os.path.join(path, p))
    new_img_array = cv2.resize(img_array, dsize=(80, 80))
    X_test.append(new_img_array)
    
X_test = np.array(X_test).reshape(-1, 80, 80, 3)
X_test = X_test / 255

# %% [markdown]
# ### Making predictions With Test Data

# %%
predictions = model.predict(X_test)
predicted_val = [int(round(p[0])) for p in predictions]
# Out:
# 391/391 [==============================] - 8s 21ms/step

# %% [markdown]
# ### Make Visualization of Accuracy Results

# %%
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]

loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(len(acc))

# %%
fig_1, ax_1 = plt.subplots(layout="constrained")
ax_1.plot(epochs, acc, "bo", label="Training Accuracy")
ax_1.plot(epochs, val_acc, "b", label="Validation Accuracy")
ax_1.set_title("Training and Validation Accuracy")
ax_1.set_xlabel("Epochs")
ax_1.set_ylabel("Accuracy")
ax_1.legend()

fig_2, ax_2 = plt.subplots(layout="constrained")
ax_2.plot(epochs, loss, "bo", label="Training Loss")
ax_2.plot(epochs, val_loss, "b", label="Validation Loss")
ax_2.set_title("Training and Validation Loss")
ax_2.set_xlabel("Epochs")
ax_2.set_ylabel("Loss")
ax_2.legend()

# %% [markdown]
# ### Notebook Interactivity

# %%
filepath = Tk().filename = filedialog.askopenfilename()
print(filepath)
file = open(filepath, "r")
Tk().mainloop()
# Out:
# C:/Users/zweifelj/Pictures/Dogs/dog-3.jpg
